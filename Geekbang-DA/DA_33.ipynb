# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G =nx.karate_club_graph()
nx.draw(G)
plt.show()

# %%
import django
print(django.get_version())
# Out:
# 2.2

# %%
str1='''
<br />\x0A<b>Notice</b>:  Undefined offset: 8 in <b>/data/www/service/application/modules/Retail/controllers/Mind.php</b> on line <b>187</b><br />\x0A{\x22status\x22:200,\x22message\x22:\x22success\x22,\x22data\x22:{\x22prize\x22:1,\x22name\x22:\x22\x5Cu6700\x5Cu5f3a\x5Cu738b\x5Cu8005\x5Cu65b0\x5Cu8f66\x5Cu793c\x5Cu53053499\x5Cu5143\x22,\x22desc\x22:\x22\x22,\x22title\x22:\x22\x5Cu5c0f\x5Cu725b\x5Cu7535\x5Cu52a8US\x5Cu90fd\x5Cu5e02\x5Cu7248\x5Cu4e00\x5Cu53f0\x22}}
'''
print(str1.encode('raw_unicode_escape').decode('utf-8'))
# Out:
# <br />
# <b>Notice</b>:  Undefined offset: 8 in <b>/data/www/service/application/modules/Retail/controllers/Mind.php</b> on line <b>187</b><br />
# {"status":200,"message":"success","data":{"prize":1,"name":"\u6700\u5f3a\u738b\u8005\u65b0\u8f66\u793c\u53053499\u5143","desc":"","title":"\u5c0f\u725b\u7535\u52a8US\u90fd\u5e02\u7248\u4e00\u53f0"}}
